# %%
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Dropout, Flatten, Dense, Activation, LeakyReLU, BatchNormalization
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # データの取得

# %%
# %matplotlib inline
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train / 255
x_test = x_test / 255
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)
print(type(x_train))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 58s 0us/step
# <class 'numpy.ndarray'>

# %%
model = Sequential()

model.add(Conv2D(32,(3,3), padding='same', input_shape=(32,32,3)))
model.add(Activation(LeakyReLU()))
model.add(Conv2D(32,(3,3),padding='same'))
model.add(Activation(LeakyReLU()))


model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation(LeakyReLU()))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation(LeakyReLU()))

model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation(LeakyReLU()))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation(LeakyReLU()))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))

model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation(LeakyReLU()))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation(LeakyReLU()))


model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation(LeakyReLU()))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation(LeakyReLU()))
model.add(Dropout(0.2))

model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation(LeakyReLU()))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation(LeakyReLU()))
model.add(MaxPool2D(pool_size=(2,2)))


model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation(LeakyReLU()))
model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation(LeakyReLU()))


model.add(Flatten())
model.add(Dense(1024))
model.add(Activation('relu'))

model.add(Dense(1024))
model.add(Activation('relu'))



model.add(Dense(512))
model.add(Activation('sigmoid'))
model.add(Dropout(0.2))

model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/activations.py:211: UserWarning: Do not pass a layer instance (such as LeakyReLU) as the activation argument of another layer. Instead, advanced activation layers should be used just like any other layer in a model.
#   identifier=identifier.__class__.__name__))
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_43 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_52 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# activation_53 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 32, 32, 64)        18496
# _________________________________________________________________
# activation_54 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 32, 32, 64)        36928
# _________________________________________________________________
# activation_55 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 32, 32, 64)        36928
# _________________________________________________________________
# activation_56 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 32, 32, 64)        36928
# _________________________________________________________________
# activation_57 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# activation_58 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# activation_59 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# activation_60 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# activation_61 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# activation_62 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_54 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# activation_63 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_55 (Conv2D)           (None, 8, 8, 64)          36928
# _________________________________________________________________
# activation_64 (Activation)   (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_56 (Conv2D)           (None, 8, 8, 64)          36928
# _________________________________________________________________
# activation_65 (Activation)   (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1024)              4195328
# _________________________________________________________________
# activation_66 (Activation)   (None, 1024)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# activation_67 (Activation)   (None, 1024)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 512)               524800
# _________________________________________________________________
# activation_68 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 6,209,706
# Trainable params: 6,209,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, batch_size=16, epochs=20, verbose=1, validation_split=0.1)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/20
# 45000/45000 [==============================] - 134s 3ms/step - loss: 2.3198 - acc: 0.0975 - val_loss: 2.3336 - val_acc: 0.0976
# Epoch 2/20
# 45000/45000 [==============================] - 133s 3ms/step - loss: 2.3204 - acc: 0.0984 - val_loss: 2.3128 - val_acc: 0.0976
# Epoch 3/20
# 45000/45000 [==============================] - 133s 3ms/step - loss: 2.3196 - acc: 0.0997 - val_loss: 2.3180 - val_acc: 0.0976
# Epoch 4/20
# 45000/45000 [==============================] - 133s 3ms/step - loss: 2.3197 - acc: 0.0993 - val_loss: 2.3103 - val_acc: 0.1038
# Epoch 5/20
# 45000/45000 [==============================] - 133s 3ms/step - loss: 2.3192 - acc: 0.1039 - val_loss: 2.3230 - val_acc: 0.1024
# Epoch 6/20
# 45000/45000 [==============================] - 133s 3ms/step - loss: 2.3182 - acc: 0.1034 - val_loss: 2.3118 - val_acc: 0.0986
# Epoch 7/20
# 45000/45000 [==============================] - 132s 3ms/step - loss: 2.3194 - acc: 0.0989 - val_loss: 2.3228 - val_acc: 0.0986
# Epoch 8/20
# 45000/45000 [==============================] - 133s 3ms/step - loss: 2.3206 - acc: 0.0990 - val_loss: 2.3207 - val_acc: 0.1058
# Epoch 9/20
# 45000/45000 [==============================] - 132s 3ms/step - loss: 2.3194 - acc: 0.1015 - val_loss: 2.3071 - val_acc: 0.1064
# Epoch 10/20
# 45000/45000 [==============================] - 133s 3ms/step - loss: 2.3187 - acc: 0.0986 - val_loss: 2.3277 - val_acc: 0.0986
# Epoch 11/20
# 45000/45000 [==============================] - 134s 3ms/step - loss: 2.3191 - acc: 0.0993 - val_loss: 2.3080 - val_acc: 0.0986
# Epoch 12/20
# 45000/45000 [==============================] - 133s 3ms/step - loss: 2.3209 - acc: 0.0986 - val_loss: 2.3165 - val_acc: 0.0976
# Epoch 13/20
# 45000/45000 [==============================] - 133s 3ms/step - loss: 2.3195 - acc: 0.0985 - val_loss: 2.3302 - val_acc: 0.0958
# Epoch 14/20
# 45000/45000 [==============================] - 133s 3ms/step - loss: 2.3203 - acc: 0.0992 - val_loss: 2.3089 - val_acc: 0.1038
# Epoch 15/20
# 45000/45000 [==============================] - 133s 3ms/step - loss: 2.3193 - acc: 0.0981 - val_loss: 2.3110 - val_acc: 0.1058
# Epoch 16/20
# 45000/45000 [==============================] - 133s 3ms/step - loss: 2.3189 - acc: 0.1009 - val_loss: 2.3094 - val_acc: 0.0986
# Epoch 17/20
# 45000/45000 [==============================] - 133s 3ms/step - loss: 2.3204 - acc: 0.1006 - val_loss: 2.3179 - val_acc: 0.0950
# Epoch 18/20
# 45000/45000 [==============================] - 133s 3ms/step - loss: 2.3202 - acc: 0.0977 - val_loss: 2.3177 - val_acc: 0.0958
# Epoch 19/20
# 45000/45000 [==============================] - 133s 3ms/step - loss: 2.3201 - acc: 0.1001 - val_loss: 2.3239 - val_acc: 0.0958
# Epoch 20/20
# 45000/45000 [==============================] - 133s 3ms/step - loss: 2.3206 - acc: 0.0984 - val_loss: 2.3126 - val_acc: 0.0976

# %%
score = model.evaluate(x_test, y_test)
print(score)
# Out:
# 10000/10000 [==============================] - 4s 447us/step
# [2.3250877521514894, 0.1]
